# %% [markdown]
# <a href="https://colab.research.google.com/github/KarinaPeinado/CursoGit-hub/blob/master/ModeloRLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("nuevo.csv")
data = data.dropna()
data.to_csv('data_new.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# Cargar el dataset de Energia
df_gas = pd.read_csv("data_new.csv")
cols = ["gas_prod_change_twh", "gas_electricity", "gas_share_energy", "gas_cons_change_twh", "gas_consumption", "gas_production", "Natural Gas /US dollars per million Btu", "Annual CO2 emissions"]
df_gas = df_gas[cols]

# Variables independientes (X)
X = df_gas[["gas_share_energy", "gas_cons_change_twh", "gas_consumption", "Natural Gas /US dollars per million Btu", "Annual CO2 emissions"]]
# Variable dependiente (y)
y = df_gas["gas_production"].values

# Dividir el dataset en conjunto de entrenamiento y conjunto de prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=0)

# Escalar los datos de prueba
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Crear y entrenar el modelo de Regresión Lineal Múltiple
regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = regressor.predict(X_test_scaled)

# Calcular el error cuadrático medio (MSE) en el conjunto de prueba
mse = mean_squared_error(y_test, y_pred)
print("Error cuadrático medio (MSE):", mse)

# Graficar los valores reales y las predicciones
plt.plot(y_test, label='Valores reales')
plt.plot(y_pred, label='Predicciones')
plt.xlabel('Índice de muestra')
plt.ylabel('Producción de gas')
plt.title('Predicción de Producción de Gas Natural')
plt.legend()
plt.show()
# Out:
# Error cuadrático medio (MSE): 114655.33790947062

# %%
df_oil = pd.read_csv("data_new.csv")
cols = ["oil_prod_change_twh", "oil_electricity", "oil_share_energy", "oil_cons_change_twh", "oil_consumption", "oil_production", "Crude Oil/US dollars per barrel", "Annual CO2 emissions"]
df_oil = df_oil[cols]

X = df_oil[["oil_share_energy", "oil_cons_change_twh", "oil_consumption", "Crude Oil/US dollars per barrel", "Annual CO2 emissions"]]
y = df_oil["oil_production"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=0)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)

y_pred = regressor.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
print("Error cuadrático medio (MSE):", mse)

plt.plot(y_test, label='Valores reales')
plt.plot(y_pred, label='Predicciones')
plt.xlabel('Índice de muestra')
plt.ylabel('Producción de combustible fosil')
plt.title('Predicción de Producción de Combustible Fosil')
plt.legend()
plt.show()
# Out:
# Error cuadrático medio (MSE): 416655.6959846853

# %%
df_coal = pd.read_csv("data_new.csv")
cols = ["coal_prod_change_twh", "coal_electricity", "coal_share_energy", "coal_cons_change_twh", "coal_consumption", "coal_production", "Coal US dollars per tonne", "Annual CO2 emissions"]
df_coal = df_coal[cols]

X = df_coal[["coal_share_energy", "coal_cons_change_twh", "coal_consumption", "Coal US dollars per tonne", "Annual CO2 emissions"]]
y = df_coal["coal_production"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=0)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)

y_pred = regressor.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
print("Error cuadrático medio (MSE):", mse)

plt.plot(y_test, label='Valores reales')
plt.plot(y_pred, label='Predicciones')
plt.xlabel('Índice de muestra')
plt.ylabel('Producción de carbón')
plt.title('Predicción de Producción de Carbón')
plt.legend()
plt.show()
# Out:
# Error cuadrático medio (MSE): 952726.7760054125

# %%
df_hydro = pd.read_csv("data_new.csv")
cols = ["Electricity from hydro (TWh)", "Hydro Generation - TWh", "Hydro (% equivalent primary energy)", "Hydro (% electricity)", "Annual CO2 emissions"]
df_hydro = df_hydro[cols]

X = df_hydro[["Hydro Generation - TWh", "Hydro (% equivalent primary energy)", "Hydro (% electricity)", "Annual CO2 emissions"]]
y = df_hydro["Electricity from hydro (TWh)"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=0)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)

y_pred = regressor.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
print("Error cuadrático medio (MSE):", mse)

plt.plot(y_test, label='Valores reales')
plt.plot(y_pred, label='Predicciones')
plt.xlabel('Índice de muestra')
plt.ylabel('Producción de energía hidráulica')
plt.title('Predicción de Producción de energía hidráulica')
plt.legend()
plt.show()
# Out:
# Error cuadrático medio (MSE): 75.72264389500998

# %%
df_solar = pd.read_csv("data_new.csv")
cols = ["Electricity from solar (TWh)", "Solar Generation - TWh", "Solar (% equivalent primary energy)", "Solar (% electricity)", "Annual CO2 emissions"]
df_solar = df_solar[cols]

X = df_solar[["Solar Generation - TWh", "Solar (% equivalent primary energy)", "Solar (% electricity)", "Annual CO2 emissions"]]
y = df_solar["Electricity from solar (TWh)"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=0)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)

y_pred_scaled = regressor.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred_scaled)
print("Error cuadrático medio (MSE):", mse)

plt.plot(y_test, label='Valores reales')
plt.plot(y_pred_scaled, label='Predicciones')
plt.xlabel('Índice de muestra')
plt.ylabel('Producción de energía solar')
plt.title('Predicción de Producción de energía solar')
plt.legend()
plt.show()
# Out:
# Error cuadrático medio (MSE): 0.2060176986000921

# %%
df_wind = pd.read_csv("data_new.csv")
cols = ["Electricity from wind (TWh)", "Wind Generation - TWh", "Wind (% equivalent primary energy)", "Wind (% electricity)", "Annual CO2 emissions"]
df_wind = df_wind[cols]

X = df_wind[["Wind Generation - TWh", "Wind (% equivalent primary energy)", "Wind (% electricity)", "Annual CO2 emissions"]]
y = df_wind["Electricity from wind (TWh)"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=0)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)

y_pred_scaled = regressor.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred_scaled)
print("Error cuadrático medio (MSE):", mse)

plt.plot(y_test, label='Valores reales')
plt.plot(y_pred_scaled, label='Predicciones')
plt.xlabel('Índice de muestra')
plt.ylabel('Producción de energía eólica')
plt.title('Predicción de Producción de energía eólica')
plt.legend()
plt.show()
# Out:
# Error cuadrático medio (MSE): 13.30783548833135
